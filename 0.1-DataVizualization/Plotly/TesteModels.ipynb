# %%
import numpy as np

# Cria uma grade no espaço [-1.5, 1.5] x [-1.5, 1.5]
x1 = np.linspace(-1.1, 1.1, 50)
x2 = np.linspace(-1.1, 1.1, 50)
X1, X2 = np.meshgrid(x1, x2)

# Empacota em um tensor para o modelo
grid = np.c_[X1.ravel(), X2.ravel()]

X_data = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])
y_data = np.array([0, 1, 1, 0])

from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier

# model = MLPClassifier((2, 50), activation='relu', max_iter=50000, learning_rate_init=0.01)
model = DecisionTreeClassifier(max_depth=3)
model.fit(X_data, y_data)

output = model.predict_proba(grid)[:, 1]

output

Z = output.reshape(X1.shape)

import plotly.io as pio
pio.renderers.default = "notebook_connected"

import plotly.graph_objects as go

fig = go.Figure()

# Superfície da saída do modelo
fig.add_trace(go.Surface(
    x=X1,
    y=X2,
    z=Z,
    colorscale='RdBu',
    opacity=0.7,
    showscale=True,
    name="Model Output"
))

# Dados reais do XOR (opcional)
# Exemplo de pontos XOR

fig.add_trace(go.Scatter3d(
    x=X_data[:, 0],
    y=X_data[:, 1],
    z=y_data,
    mode='markers',
    marker=dict(
        size=6,
        color=y_data,
        colorscale='RdBu',
        line=dict(width=1)
    ),
    name='XOR Data'
))

fig.update_layout(
    title='XOR Model Decision Surface',
    scene=dict(
        xaxis_title='Feature 1',
        yaxis_title='Feature 2',
        zaxis_title='Output / Label'
    )
)
fig.update_layout(
    title='XOR Model Decision Surface',
    scene=dict(
        xaxis=dict(title='Feature 1', range=[-0.2, 1.2]),
        yaxis=dict(title='Feature 2', range=[-0.2, 1.2]),
        zaxis=dict(title='Output / Label'),
    ),
    width=800,
    height=600
)
fig.show()

from plotly.subplots import make_subplots

# ==== Cria subplots com 2 cenas 3D ====
fig = make_subplots(
    rows=1, cols=2,
    specs=[[{'type': 'scene'}, {'type': 'scene'}]],  # Dois gráficos 3D
    subplot_titles=("Superfície do Modelo", "Pontos XOR")
)

# ==== Primeiro gráfico: Superfície ====
fig.add_trace(go.Surface(
    x=X1,
    y=X2,
    z=Z,
    colorscale='RdBu',
    opacity=0.7,
    showscale=False,
    name="Model Output"
), row=1, col=1)
fig.add_trace(go.Scatter3d(
    x=X_data[:, 0],
    y=X_data[:, 1],
    z=y_data,
    mode='markers',
    marker=dict(
        size=6,
        color=y_data,
        colorscale='RdBu',
        line=dict(width=1)
    ),
    name='XOR Data'
), row=1, col=1)

# ==== Segundo gráfico: Pontos do XOR ====
fig.add_trace(go.Scatter3d(
    x=X_data[:, 0],
    y=X_data[:, 1],
    z=y_data,
    mode='markers',
    marker=dict(
        size=8,
        color=y_data,
        colorscale='RdBu',
        line=dict(width=2, color='black')
    ),
    name='XOR Data'
), row=1, col=2)

# ==== Configura os eixos de cada subplot ====
fig.update_layout(
    scene=dict(
        xaxis=dict(title='Feature 1', range=[-0.2, 1.2]),
        yaxis=dict(title='Feature 2', range=[-0.2, 1.2]),
        zaxis=dict(title='Output / Label')
    ),
    scene2=dict(
        xaxis=dict(title='Feature 1', range=[-0.2, 1.2]),
        yaxis=dict(title='Feature 2', range=[-0.2, 1.2]),
        zaxis=dict(title='Output / Label')
    ),
    title="XOR Model Surface and Data Points",
    width=1000,
    height=600
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="1762b9b4-d493-4315-864e-3ee5251cc564" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1762b9b4-d493-4315-864e-3ee5251cc564")) {                    Plotly.newPlot(                        "1762b9b4-d493-4315-864e-3ee5251cc564",                        [{"colorscale":[[0.0,"rgb(103,0,31)"],[0.1,"rgb(178,24,43)"],[0.2,"rgb(214,96,77)"],[0.3,"rgb(244,165,130)"],[0.4,"rgb(253,219,199)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(209,229,240)"],[0.7,"rgb(146,197,222)"],[0.8,"rgb(67,147,195)"],[0.9,"rgb(33,102,172)"],[1.0,"rgb(5,48,97)"]],"name":"Model Output","opacity":0.7,"showscale":true,"x":{"dtype":"f8","bdata":"mpmZmZmZ8b\u002fS+3OtsuHwvwteTsHLKfC\u002fhoBRqsnj7r\u002f3RAbS+3Ptv2gJu\u002fktBOy\u002f2c1vIWCU6r9KkiRJkiTpv7pW2XDEtOe\u002fLBuOmPZE5r+c30LAKNXkvw2k9+daZeO\u002ffmisD4314b\u002fvLGE3v4Xgv77iK77iK96\u002foGuVDUdM27+C9P5cq2zYv2R9aKwPjdW\u002fRgbS+3Ot0r9MHneWsJvPvxAwSjV53Mm\u002f1EEd1EEdxL8wp+DlFLy8v7DKhiOmPbG\u002fALmzhN38lr8AubOE3fyWP7DKhiOmPbE\u002fMKfg5RS8vD\u002fYQR3UQR3EPxAwSjV53Mk\u002fUB53lrCbzz9EBtL7c63SP2R9aKwPjdU\u002fhPT+XKts2D+ga5UNR0zbP8DiK77iK94\u002f7ixhN7+F4D9+aKwPjfXhPw6k9+daZeM\u002fnN9CwCjV5D8sG46Y9kTmP7pW2XDEtOc\u002fSpIkSZIk6T\u002fazW8hYJTqP2gJu\u002fktBOw\u002f+EQG0vtz7T+IgFGqyePuPwpeTsHLKfA\u002f0vtzrbLh8D+amZmZmZnxP5qZmZmZmfG\u002f0vtzrbLh8L8LXk7Byynwv4aAUarJ4+6\u002f90QG0vtz7b9oCbv5LQTsv9nNbyFglOq\u002fSpIkSZIk6b+6VtlwxLTnvywbjpj2ROa\u002fnN9CwCjV5L8NpPfnWmXjv35orA+N9eG\u002f7yxhN7+F4L++4iu+4ivev6BrlQ1HTNu\u002fgvT+XKts2L9kfWisD43Vv0YG0vtzrdK\u002fTB53lrCbz78QMEo1edzJv9RBHdRBHcS\u002fMKfg5RS8vL+wyoYjpj2xvwC5s4Td\u002fJa\u002fALmzhN38lj+wyoYjpj2xPzCn4OUUvLw\u002f2EEd1EEdxD8QMEo1edzJP1Aed5awm88\u002fRAbS+3Ot0j9kfWisD43VP4T0\u002flyrbNg\u002foGuVDUdM2z\u002fA4iu+4iveP+4sYTe\u002fheA\u002ffmisD4314T8OpPfnWmXjP5zfQsAo1eQ\u002fLBuOmPZE5j+6VtlwxLTnP0qSJEmSJOk\u002f2s1vIWCU6j9oCbv5LQTsP\u002fhEBtL7c+0\u002fiIBRqsnj7j8KXk7ByynwP9L7c62y4fA\u002fmpmZmZmZ8T+amZmZmZnxv9L7c62y4fC\u002fC15Owcsp8L+GgFGqyePuv\u002fdEBtL7c+2\u002faAm7+S0E7L\u002fZzW8hYJTqv0qSJEmSJOm\u002fulbZcMS0578sG46Y9kTmv5zfQsAo1eS\u002fDaT351pl479+aKwPjfXhv+8sYTe\u002fheC\u002fvuIrvuIr3r+ga5UNR0zbv4L0\u002flyrbNi\u002fZH1orA+N1b9GBtL7c63Sv0wed5awm8+\u002fEDBKNXncyb\u002fUQR3UQR3EvzCn4OUUvLy\u002fsMqGI6Y9sb8AubOE3fyWvwC5s4Td\u002fJY\u002fsMqGI6Y9sT8wp+DlFLy8P9hBHdRBHcQ\u002fEDBKNXncyT9QHneWsJvPP0QG0vtzrdI\u002fZH1orA+N1T+E9P5cq2zYP6BrlQ1HTNs\u002fwOIrvuIr3j\u002fuLGE3v4XgP35orA+N9eE\u002fDqT351pl4z+c30LAKNXkPywbjpj2ROY\u002fulbZcMS05z9KkiRJkiTpP9rNbyFglOo\u002faAm7+S0E7D\u002f4RAbS+3PtP4iAUarJ4+4\u002fCl5Owcsp8D\u002fS+3OtsuHwP5qZmZmZmfE\u002fmpmZmZmZ8b\u002fS+3OtsuHwvwteTsHLKfC\u002fhoBRqsnj7r\u002f3RAbS+3Ptv2gJu\u002fktBOy\u002f2c1vIWCU6r9KkiRJkiTpv7pW2XDEtOe\u002fLBuOmPZE5r+c30LAKNXkvw2k9+daZeO\u002ffmisD4314b\u002fvLGE3v4Xgv77iK77iK96\u002foGuVDUdM27+C9P5cq2zYv2R9aKwPjdW\u002fRgbS+3Ot0r9MHneWsJvPvxAwSjV53Mm\u002f1EEd1EEdxL8wp+DlFLy8v7DKhiOmPbG\u002fALmzhN38lr8AubOE3fyWP7DKhiOmPbE\u002fMKfg5RS8vD\u002fYQR3UQR3EPxAwSjV53Mk\u002fUB53lrCbzz9EBtL7c63SP2R9aKwPjdU\u002fhPT+XKts2D+ga5UNR0zbP8DiK77iK94\u002f7ixhN7+F4D9+aKwPjfXhPw6k9+daZeM\u002fnN9CwCjV5D8sG46Y9kTmP7pW2XDEtOc\u002fSpIkSZIk6T\u002fazW8hYJTqP2gJu\u002fktBOw\u002f+EQG0vtz7T+IgFGqyePuPwpeTsHLKfA\u002f0vtzrbLh8D+amZmZmZnxP5qZmZmZmfG\u002f0vtzrbLh8L8LXk7Byynwv4aAUarJ4+6\u002f90QG0vtz7b9oCbv5LQTsv9nNbyFglOq\u002fSpIkSZIk6b+6VtlwxLTnvywbjpj2ROa\u002fnN9CwCjV5L8NpPfnWmXjv35orA+N9eG\u002f7yxhN7+F4L++4iu+4ivev6BrlQ1HTNu\u002fgvT+XKts2L9kfWisD43Vv0YG0vtzrdK\u002fTB53lrCbz78QMEo1edzJv9RBHdRBHcS\u002fMKfg5RS8vL+wyoYjpj2xvwC5s4Td\u002fJa\u002fALmzhN38lj+wyoYjpj2xPzCn4OUUvLw\u002f2EEd1EEdxD8QMEo1edzJP1Aed5awm88\u002fRAbS+3Ot0j9kfWisD43V ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="fdf13c63-17f0-4491-bd52-b034de9b5f5a" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fdf13c63-17f0-4491-bd52-b034de9b5f5a")) {                    Plotly.newPlot(                        "fdf13c63-17f0-4491-bd52-b034de9b5f5a",                        [{"colorscale":[[0.0,"rgb(103,0,31)"],[0.1,"rgb(178,24,43)"],[0.2,"rgb(214,96,77)"],[0.3,"rgb(244,165,130)"],[0.4,"rgb(253,219,199)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(209,229,240)"],[0.7,"rgb(146,197,222)"],[0.8,"rgb(67,147,195)"],[0.9,"rgb(33,102,172)"],[1.0,"rgb(5,48,97)"]],"name":"Model Output","opacity":0.7,"showscale":false,"x":{"dtype":"f8","bdata":"mpmZmZmZ8b\u002fS+3OtsuHwvwteTsHLKfC\u002fhoBRqsnj7r\u002f3RAbS+3Ptv2gJu\u002fktBOy\u002f2c1vIWCU6r9KkiRJkiTpv7pW2XDEtOe\u002fLBuOmPZE5r+c30LAKNXkvw2k9+daZeO\u002ffmisD4314b\u002fvLGE3v4Xgv77iK77iK96\u002foGuVDUdM27+C9P5cq2zYv2R9aKwPjdW\u002fRgbS+3Ot0r9MHneWsJvPvxAwSjV53Mm\u002f1EEd1EEdxL8wp+DlFLy8v7DKhiOmPbG\u002fALmzhN38lr8AubOE3fyWP7DKhiOmPbE\u002fMKfg5RS8vD\u002fYQR3UQR3EPxAwSjV53Mk\u002fUB53lrCbzz9EBtL7c63SP2R9aKwPjdU\u002fhPT+XKts2D+ga5UNR0zbP8DiK77iK94\u002f7ixhN7+F4D9+aKwPjfXhPw6k9+daZeM\u002fnN9CwCjV5D8sG46Y9kTmP7pW2XDEtOc\u002fSpIkSZIk6T\u002fazW8hYJTqP2gJu\u002fktBOw\u002f+EQG0vtz7T+IgFGqyePuPwpeTsHLKfA\u002f0vtzrbLh8D+amZmZmZnxP5qZmZmZmfG\u002f0vtzrbLh8L8LXk7Byynwv4aAUarJ4+6\u002f90QG0vtz7b9oCbv5LQTsv9nNbyFglOq\u002fSpIkSZIk6b+6VtlwxLTnvywbjpj2ROa\u002fnN9CwCjV5L8NpPfnWmXjv35orA+N9eG\u002f7yxhN7+F4L++4iu+4ivev6BrlQ1HTNu\u002fgvT+XKts2L9kfWisD43Vv0YG0vtzrdK\u002fTB53lrCbz78QMEo1edzJv9RBHdRBHcS\u002fMKfg5RS8vL+wyoYjpj2xvwC5s4Td\u002fJa\u002fALmzhN38lj+wyoYjpj2xPzCn4OUUvLw\u002f2EEd1EEdxD8QMEo1edzJP1Aed5awm88\u002fRAbS+3Ot0j9kfWisD43VP4T0\u002flyrbNg\u002foGuVDUdM2z\u002fA4iu+4iveP+4sYTe\u002fheA\u002ffmisD4314T8OpPfnWmXjP5zfQsAo1eQ\u002fLBuOmPZE5j+6VtlwxLTnP0qSJEmSJOk\u002f2s1vIWCU6j9oCbv5LQTsP\u002fhEBtL7c+0\u002fiIBRqsnj7j8KXk7ByynwP9L7c62y4fA\u002fmpmZmZmZ8T+amZmZmZnxv9L7c62y4fC\u002fC15Owcsp8L+GgFGqyePuv\u002fdEBtL7c+2\u002faAm7+S0E7L\u002fZzW8hYJTqv0qSJEmSJOm\u002fulbZcMS0578sG46Y9kTmv5zfQsAo1eS\u002fDaT351pl479+aKwPjfXhv+8sYTe\u002fheC\u002fvuIrvuIr3r+ga5UNR0zbv4L0\u002flyrbNi\u002fZH1orA+N1b9GBtL7c63Sv0wed5awm8+\u002fEDBKNXncyb\u002fUQR3UQR3EvzCn4OUUvLy\u002fsMqGI6Y9sb8AubOE3fyWvwC5s4Td\u002fJY\u002fsMqGI6Y9sT8wp+DlFLy8P9hBHdRBHcQ\u002fEDBKNXncyT9QHneWsJvPP0QG0vtzrdI\u002fZH1orA+N1T+E9P5cq2zYP6BrlQ1HTNs\u002fwOIrvuIr3j\u002fuLGE3v4XgP35orA+N9eE\u002fDqT351pl4z+c30LAKNXkPywbjpj2ROY\u002fulbZcMS05z9KkiRJkiTpP9rNbyFglOo\u002faAm7+S0E7D\u002f4RAbS+3PtP4iAUarJ4+4\u002fCl5Owcsp8D\u002fS+3OtsuHwP5qZmZmZmfE\u002fmpmZmZmZ8b\u002fS+3OtsuHwvwteTsHLKfC\u002fhoBRqsnj7r\u002f3RAbS+3Ptv2gJu\u002fktBOy\u002f2c1vIWCU6r9KkiRJkiTpv7pW2XDEtOe\u002fLBuOmPZE5r+c30LAKNXkvw2k9+daZeO\u002ffmisD4314b\u002fvLGE3v4Xgv77iK77iK96\u002foGuVDUdM27+C9P5cq2zYv2R9aKwPjdW\u002fRgbS+3Ot0r9MHneWsJvPvxAwSjV53Mm\u002f1EEd1EEdxL8wp+DlFLy8v7DKhiOmPbG\u002fALmzhN38lr8AubOE3fyWP7DKhiOmPbE\u002fMKfg5RS8vD\u002fYQR3UQR3EPxAwSjV53Mk\u002fUB53lrCbzz9EBtL7c63SP2R9aKwPjdU\u002fhPT+XKts2D+ga5UNR0zbP8DiK77iK94\u002f7ixhN7+F4D9+aKwPjfXhPw6k9+daZeM\u002fnN9CwCjV5D8sG46Y9kTmP7pW2XDEtOc\u002fSpIkSZIk6T\u002fazW8hYJTqP2gJu\u002fktBOw\u002f+EQG0vtz7T+IgFGqyePuPwpeTsHLKfA\u002f0vtzrbLh8D+amZmZmZnxP5qZmZmZmfG\u002f0vtzrbLh8L8LXk7Byynwv4aAUarJ4+6\u002f90QG0vtz7b9oCbv5LQTsv9nNbyFglOq\u002fSpIkSZIk6b+6VtlwxLTnvywbjpj2ROa\u002fnN9CwCjV5L8NpPfnWmXjv35orA+N9eG\u002f7yxhN7+F4L++4iu+4ivev6BrlQ1HTNu\u002fgvT+XKts2L9kfWisD43Vv0YG0vtzrdK\u002fTB53lrCbz78QMEo1edzJv9RBHdRBHcS\u002fMKfg5RS8vL+wyoYjpj2xvwC5s4Td\u002fJa\u002fALmzhN38lj+wyoYjpj2xPzCn4OUUvLw\u002f2EEd1EEdxD8QMEo1edzJP1Aed5awm88\u002fRAbS+3Ot0j9kfWisD4 ...
